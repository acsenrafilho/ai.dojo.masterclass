# %% [markdown]
# # Hello World!
#
# Apenas um exemplos de Colab

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # Somente mais um teste de Markdown
#
# Isso sim que é markdown, hein!

# %%
print("Esse minino vale ouro!")
# Out:
# Esse minino vale ouro!
